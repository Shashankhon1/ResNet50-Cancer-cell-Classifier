# %% [markdown]
# <a href="https://colab.research.google.com/github/Shashankhon1/ResNet50-Cancer-cell-Classifier/blob/main/Breast_cancer_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loading & Preprocessing

# %%
import json
import math
import os

import cv2
from PIL import Image
import numpy as np
from keras import layers
from keras.applications.resnet import ResNet50
from keras.applications.densenet import DenseNet201
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.optimizers import adam_v2
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import cohen_kappa_score, accuracy_score
import scipy
from tqdm import tqdm
import tensorflow as tf
from keras import backend as K
import gc
from functools import partial
from sklearn import metrics
from collections import Counter
import json
import itertools


# %matplotlib inline

# %%
Adam=adam_v2.Adam

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
subdir1=[]
dir1="/content/drive/MyDrive/SRE_01_Capstone_Material/BreaKHis_v1/40X/40X-benign/"
for dir in os.listdir(dir1):
  subdir1.append(dir)

# %%
len(subdir1)
# Out:
# 16

# %%
subdir2=[]
dir2="/content/drive/MyDrive/SRE_01_Capstone_Material/BreaKHis_v1/40X/40X-malignant/"
for dir in os.listdir(dir2):
  subdir2.append(dir)

# %%
len(subdir2)
# Out:
# 36

# %%
subdir2
# Out:
# ['40X-7',
#  '40X-32',
#  '40X',
#  '40X-9',
#  '40X-27',
#  '40X-23',
#  '40X-1',
#  '40X-4',
#  '40X-17',
#  '40X-2',
#  '40X-24',
#  '40X-8',
#  '40X-13',
#  '40X-25',
#  '40X-29',
#  '40X-14',
#  '40X-5',
#  '40X-22',
#  '40X-15',
#  '40X-35',
#  '40X-30',
#  '40X-26',
#  '40X-21',
#  '40X-6',
#  '40X-19',
#  '40X-34',
#  '40X-18',
#  '40X-31',
#  '40X-11',
#  '40X-28',
#  '40X-20',
#  '40X-12',
#  '40X-16',
#  '40X-10',
#  '40X-3',
#  '40X-33']

# %%
#Transfer 'jpg' images to an array IMG
def Dataset_loader(DIR, RESIZE, sigmaX=10):
    IMG = []
    read = lambda imname: np.asarray(Image.open(imname).convert("RGB"))
    for IMAGE_NAME in tqdm(os.listdir(DIR)):
        PATH = os.path.join(DIR,IMAGE_NAME)
        _, ftype = os.path.splitext(PATH)
        if ftype == ".png":
            img = read(PATH)
           
            img = cv2.resize(img, (RESIZE,RESIZE))
           
            IMG.append(np.array(img))
    return IMG

# %%
benign=[]
for i in subdir1:
  benign.append(np.array(Dataset_loader(dir1+i,224)))
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 57.63it/s]
# 100%|██████████| 16/16 [00:00<00:00, 77.51it/s]
# 100%|██████████| 38/38 [00:00<00:00, 57.96it/s]
# 100%|██████████| 13/13 [00:00<00:00, 55.16it/s]
# 100%|██████████| 2/2 [00:00<00:00, 53.48it/s]
# 100%|██████████| 16/16 [00:00<00:00, 80.97it/s]
# 100%|██████████| 18/18 [00:00<00:00, 87.37it/s]
# 100%|██████████| 22/22 [00:00<00:00, 56.34it/s]
# 100%|██████████| 35/35 [00:00<00:00, 63.59it/s]
# 100%|██████████| 36/36 [00:00<00:00, 57.26it/s]
# 100%|██████████| 26/26 [00:00<00:00, 58.76it/s]
# 100%|██████████| 39/39 [00:00<00:00, 55.07it/s]
# 100%|██████████| 14/14 [00:00<00:00, 88.67it/s]
# 100%|██████████| 13/13 [00:00<00:00, 56.81it/s]
# 100%|██████████| 16/16 [00:00<00:00, 84.58it/s]
# 100%|██████████| 31/31 [00:00<00:00, 59.50it/s]

# %%
malignant=[]
for i in subdir2:
  malignant.append(np.array(Dataset_loader(dir2+i,224)))
# Out:
# 100%|██████████| 14/14 [00:00<00:00, 61.90it/s]
# 100%|██████████| 17/17 [00:13<00:00,  1.27it/s]
# 100%|██████████| 72/72 [00:01<00:00, 64.88it/s]
# 100%|██████████| 23/23 [00:00<00:00, 56.49it/s]
# 100%|██████████| 15/15 [00:11<00:00,  1.28it/s]
# 100%|██████████| 26/26 [00:20<00:00,  1.28it/s]
# 100%|██████████| 26/26 [00:00<00:00, 57.21it/s]
# 100%|██████████| 23/23 [00:00<00:00, 54.92it/s]
# 100%|██████████| 29/29 [00:21<00:00,  1.35it/s]
# 100%|██████████| 23/23 [00:00<00:00, 56.77it/s]
# 100%|██████████| 29/29 [00:22<00:00,  1.27it/s]
# 100%|██████████| 31/31 [00:00<00:00, 43.55it/s]
# 100%|██████████| 13/13 [00:00<00:00, 44.32it/s]
# 100%|██████████| 15/15 [00:12<00:00,  1.17it/s]
# 100%|██████████| 26/26 [00:20<00:00,  1.27it/s]
# 100%|██████████| 11/11 [00:00<00:00, 61.12it/s]
# 100%|██████████| 10/10 [00:00<00:00, 56.18it/s]
# 100%|██████████| 15/15 [00:12<00:00,  1.22it/s]
# 100%|██████████| 12/12 [00:00<00:00, 58.71it/s]
# 100%|██████████| 19/19 [00:13<00:00,  1.38it/s]
# 100%|██████████| 17/17 [00:13<00:00,  1.25it/s]
# 100%|██████████| 46/46 [00:33<00:00,  1.36it/s]
# 100%|██████████| 22/22 [00:17<00:00,  1.29it/s]
# 100%|██████████| 26/26 [00:00<00:00, 89.87it/s]
# 100%|██████████| 51/51 [00:39<00:00,  1.29it/s]
# 100%|██████████| 35/35 [00:27<00:00,  1.28it/s]
# 100%|██████████| 32/32 [00:24<00:00,  1.29it/s]
# 100%|██████████| 23/23 [00:17<00:00,  1.32it/s]
# 100%|██████████| 14/14 [00:00<00:00, 60.80it/s]
# 100%|██████████| 16/16 [00:12<00:00,  1.23it/s]
# 100%|██████████| 31/31 [00:25<00:00,  1.22it/s]
# 100%|██████████| 24/24 [00:00<00:00, 39.90it/s]
# 100%|██████████| 26/26 [00:19<00:00,  1.37it/s]
# 100%|██████████| 23/23 [00:00<00:00, 56.16it/s]
# 100%|██████████| 22/22 [00:00<00:00, 56.77it/s]
# 100%|██████████| 30/30 [00:23<00:00,  1.28it/s]

# %%
import random

# %%
from sklearn.model_selection import train_test_split

# %%
len(benign)
# Out:
# 16

# %%
Benign=[]
for i in benign:
  for j in i:
    Benign.append(j)

# %%
Malign=[]
for i in malignant:
  for j in i:
    Malign.append(j)

# %%
random.shuffle(Benign)
benign_test, benign_train = train_test_split(Benign, train_size=0.75, test_size=0.25)

# %%
random.shuffle(Malign)
malign_test, malign_train = train_test_split(Malign, train_size=0.75, test_size=0.25)

# %% [markdown]
# # Create Label

# %%
# Skin Cancer: Malignant vs. Benign
# Create labels
benign_train_label = np.zeros(len(benign_train))
malign_train_label = np.ones(len(malign_train))
benign_test_label = np.zeros(len(benign_test))
malign_test_label = np.ones(len(malign_test))

# Merge data 
X_train = np.concatenate((benign_train, malign_train), axis = 0)
Y_train = np.concatenate((benign_train_label, malign_train_label), axis = 0)
X_test = np.concatenate((benign_test, malign_test), axis = 0)
Y_test = np.concatenate((benign_test_label, malign_test_label), axis = 0)

# Shuffle train data
s = np.arange(X_train.shape[0])
np.random.shuffle(s)
X_train = X_train[s]
Y_train = Y_train[s]

# Shuffle test data
s = np.arange(X_test.shape[0])
np.random.shuffle(s)
X_test = X_test[s]
Y_test = Y_test[s]

# To categorical
Y_train = to_categorical(Y_train, num_classes= 2)
Y_test = to_categorical(Y_test, num_classes= 2)

# %% [markdown]
# # Train and Evalutation split

# %%
x_train, x_val, y_train, y_val = train_test_split(
    X_train, Y_train, 
    test_size=0.2, 
    random_state=11
)

# %% [markdown]
# # Display Some Images

# %%
w=60
h=40
fig=plt.figure(figsize=(15, 15))
columns = 2
rows = 2

for i in range(1, columns*rows +1):
    ax = fig.add_subplot(rows, columns, i)
    if np.argmax(Y_train[i]) == 0:
        ax.title.set_text('Benign')
    else:
        ax.title.set_text('Malignant')
    plt.imshow(x_train[i], interpolation='nearest')
plt.show()

# %% [markdown]
# # Data Generator

# %%
BATCH_SIZE = 8

# Using original generator
train_generator = ImageDataGenerator(
        zoom_range=2,  # set range for random zoom
        rotation_range = 90,
        horizontal_flip=True,  # randomly flip images
        vertical_flip=True,  # randomly flip images
    )

# %% [markdown]
# # Model: ResNet50

# %%
def build_model(backbone, lr=1e-4):
    model = Sequential()
    model.add(backbone)
    model.add(layers.GlobalAveragePooling2D())
    model.add(layers.Dropout(0.5))
    model.add(layers.BatchNormalization())
    model.add(layers.Dense(2, activation='softmax'))
    
    
    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(lr=lr),
        metrics=['accuracy'],
    )
    
    return model

# %%
K.clear_session()
gc.collect()

resnet = DenseNet201(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)


 


model = build_model(resnet ,lr = 1e-4)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 7, 7, 1920)        18321984
#
#  global_average_pooling2d (G  (None, 1920)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1920)              0
#
#  batch_normalization (BatchN  (None, 1920)             7680
#  ormalization)
#
#  dense (Dense)               (None, 2)                 3842
#
# =================================================================
# Total params: 18,333,506
# Trainable params: 18,100,610
# Non-trainable params: 232,896
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# Learning Rate Reducer
learn_control = ReduceLROnPlateau(monitor='val_acc', patience=5,
                                  verbose=1,factor=0.2, min_lr=1e-7)

# Checkpoint
filepath="/content/weights_best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %% [markdown]
# # Training & Evaluation

# %%
history = model.fit_generator(
    train_generator.flow(x_train, y_train, batch_size=BATCH_SIZE),
    steps_per_epoch=x_train.shape[0] / BATCH_SIZE,
    epochs=20,
    validation_data=(x_val, y_val),
    callbacks=[learn_control, checkpoint]
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# 32/31 [==============================] - ETA: 0s - loss: 0.2888 - accuracy: 0.8760WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 31/31 [==============================] - 6s 181ms/step - loss: 0.2888 - accuracy: 0.8760 - val_loss: 0.3368 - val_accuracy: 0.9048 - lr: 1.0000e-04
# Epoch 2/20
# 32/31 [==============================] - ETA: 0s - loss: 0.2661 - accuracy: 0.9000WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 31/31 [==============================] - 6s 180ms/step - loss: 0.2661 - accuracy: 0.9000 - val_loss: 0.3325 - val_accuracy: 0.8571 - lr: 1.0000e-04
# Epoch 3/20
# 32/31 [==============================] - ETA: 0s - loss: 0.1921 - accuracy: 0.9320WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 31/31 [==============================] - 6s 184ms/step - loss: 0.1921 - accuracy: 0.9320 - val_loss: 0.4126 - val_accuracy: 0.8730 - lr: 1.0000e-04
# Epoch 4/20
# 32/31 [==============================] - ETA: 0s - loss: 0.2548 - accuracy: 0.9160WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 31/31 [==============================] - 6s 182ms/step - loss: 0.2548 - accuracy: 0.9160 - val_loss: 0.3724 - val_accuracy: 0.9048 - lr: 1.0000e-04
# Epoch 5/20
# 32/31 [==============================] - ETA: 0s - loss: 0.1939 - accuracy: 0.9320WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 31/31 [==============================] - 6s 183ms/step - loss: 0.1939 - accuracy: 0.9320 - val_loss: 0.3068 - val_accuracy: 0.9206 - lr: 1.0000e-04
# Epoch 6/20
# 32/31 [==============================] - ETA: 0s - loss: 0.2371 - accuracy: 0.9120WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 31/31 [==============================] - 6s 183ms/step - loss: 0.2371 - accuracy: 0.9120 - val_loss: 0.7073 - val_accuracy: 0.8254 - lr: 1.0000e-04
# Epoch 7/20
# 32/31 [==============================] - ETA: 0s - loss: 0.1982 - accuracy: 0.9360WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 31/31 [==============================] - 6s 181ms/step - loss: 0.1982 - accuracy: 0.9360 - val_loss: 0.7319 - val_accuracy: 0.7778 - lr: 1.0000e-04
# Epoch 8/20
# 32/31 [==============================] - ETA: 0s - loss: 0.2623 - accuracy: 0.8920WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 31/31 [==============================] - 6s 185ms/step - loss: 0.2623 - accuracy: 0.8920 - val_loss: 0.4661 - val_accuracy: 0.8254 - lr: 1.0000e-04
# Epoch 9/20
# 32/31 [==============================] - ETA: 0s - loss: 0.2328 - accuracy: 0.9040WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 31/31 [==============================] - 6s 186ms/step - loss: 0.2328 - accuracy: 0.9040 - val_loss: 0.7270 - val_accuracy: 0.7778 - lr: 1.0000e-04
# Epoch 10/20
# 32/31 [==============================] - ETA: 0s - loss: 0.2287 - accuracy: 0.9200WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 31/31 [==============================] - 6s 185ms/step - loss: 0.2287 - accuracy: 0.9200 - val_loss: 0.6881 - val_accuracy: 0.8095 - lr: 1.0000e-04
# Epoch 11/20
# 32/31 [==============================] - ETA: 0s - loss: 0.1886 - accuracy: 0.9240WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 31/31 [==============================] - 6s 185ms/step - loss: 0.1886 - accuracy: 0.9240 - val_loss: 0.3228 - val_accuracy: 0.8889 - lr: 1.0000e-04
# Epoch 12/20
# 32/31 [==============================] - ETA: 0s - loss: 0.2883 - accuracy: 0.8960WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 31/31 [==============================] - 6s 184ms/step - loss: 0.2883 - accuracy: 0.8960 - val_loss: 0.4269 - val_accuracy: 0.8889 - lr: 1.0000e-04
# Epoch 13/20
# 32/31 [==============================] - ETA: 0s - loss: 0.3480 - accuracy: 0.8680WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 31/31 [==============================] - 6s 182ms/step - loss: 0.3480 - accuracy: 0.8680 - val_loss: 0.3724 - val_accuracy: 0.8571 - lr: 1.0000e-04
# Epoch 14/20
# 32/31 [==============================] - ETA: 0s - loss: 0.2005 - accuracy: 0.9280WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 31/31 [==============================] - 6s 183ms/step - loss: 0.2005 - accuracy: 0.9280 - val_loss: 0.2771 - val_accuracy: 0.9206 - lr: 1.0000e-04
# Epoch 15/20
# 32/31 [==============================] - ETA: 0s - loss: 0.2104 - accuracy: 0.9240WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 31/31 [==============================] - 6s 182ms/step - loss: 0.2104 - accuracy: 0.9240 - val_loss: 0.3962 - val_accuracy: 0.8889 - lr: 1.0000e-04
# Epoch 16/20
# 32/31 [==============================] - ETA: 0s - loss: 0.2492 - accuracy: 0.9160WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 31/31 [==============================] - 6s 182ms/step - loss: 0.2492 - accuracy: 0.9160 - val_loss: 0.3549 - val_accuracy: 0.9048 - lr: 1.0000e-04
# Epoch 17/20
# 32/31 [==============================] - ETA: 0s - loss: 0.2175 - accuracy: 0.9320WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 31/31 [==============================] - 6s 182ms/step - loss: 0.2175 - accuracy: 0.9320 - val_loss: 0.2724 - val_accuracy: 0.9524 - lr: 1.0000e-04
# Epoch 18/20
# 32/31 [==============================] - ETA: 0s - loss: 0.2594 - accuracy: 0.8920WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 31/31 [==============================] - 6s 182ms/step - loss: 0.2594 - accuracy: 0.8920 - val_loss: 0.2834 - val_accuracy: 0.9365 - lr: 1.0000e-04
# Epoch 19/20
# 32/31 [==============================] - ETA: 0s - loss: 0.1823 - accuracy: 0.9360WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 31/31 [==============================] - 6s 183ms/step - loss: 0.1823 - accuracy: 0.9360 - val_loss: 0.5690 - val_accuracy: 0.8730 - lr: 1.0000e-04
# Epoch 20/20
# 32/31 [==============================] - ETA: 0s - loss: 0.2394 - accuracy: 0.9080WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 31/31 [==============================] - 6s 183ms/step - loss: 0.2394 - accuracy: 0.9080 - val_loss: 0.2992 - val_accuracy: 0.9048 - lr: 1.0000e-04

# %%
with open('history.json', 'w') as f:
  json.dump(str(history.history), f)

# %%
history_df = pd.DataFrame(history.history)
history_df[['accuracy', 'val_accuracy']].plot()

# %%
history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot()

# %% [markdown]
# # Prediction

# %%
model.load_weights("weights_best.hdf5")

# %%
Y_val_pred = model.predict(x_val)

# %%
Y_val_pred
# Out:
# array([[2.8929819e-04, 9.9971062e-01],
#        [9.9999821e-01, 1.8174700e-06],
#        [1.2824693e-04, 9.9987173e-01],
#        [1.0000000e+00, 1.9035026e-08],
#        [2.6970037e-08, 1.0000000e+00],
#        [1.4560742e-05, 9.9998546e-01],
#        [8.8102147e-03, 9.9118984e-01],
#        [4.7282188e-07, 9.9999952e-01],
#        [3.7005013e-03, 9.9629956e-01],
#        [4.9501716e-07, 9.9999952e-01],
#        [2.2137488e-05, 9.9997783e-01],
#        [2.9804752e-08, 1.0000000e+00],
#        [7.7114642e-10, 1.0000000e+00],
#        [6.8363391e-08, 9.9999988e-01],
#        [6.1375104e-06, 9.9999392e-01],
#        [9.9996829e-01, 3.1674579e-05],
#        [9.9987662e-01, 1.2336399e-04],
#        [6.6993193e-06, 9.9999332e-01],
#        [2.1544910e-09, 1.0000000e+00],
#        [2.5089586e-09, 1.0000000e+00],
#        [9.7001439e-01, 2.9985605e-02],
#        [2.4141655e-06, 9.9999762e-01],
#        [9.9999619e-01, 3.7657519e-06],
#        [7.6638544e-06, 9.9999237e-01],
#        [4.4414223e-06, 9.9999559e-01],
#        [9.9986076e-01, 1.3915967e-04],
#        [6.1931796e-02, 9.3806815e-01],
#        [2.7062129e-07, 9.9999976e-01],
#        [5.1165581e-01, 4.8834422e-01],
#        [9.9999094e-01, 9.0229314e-06],
#        [1.2264829e-06, 9.9999881e-01],
#        [3.0607003e-04, 9.9969399e-01],
#        [9.9999869e-01, 1.3162709e-06],
#        [6.1299073e-07, 9.9999940e-01],
#        [3.6033243e-03, 9.9639672e-01],
#        [5.2715122e-04, 9.9947292e-01],
#        [5.0528746e-05, 9.9994946e-01],
#        [9.9986005e-01, 1.3995133e-04],
#        [2.1622066e-06, 9.9999785e-01],
#        [2.6198541e-07, 9.9999976e-01],
#        [2.9021819e-06, 9.9999714e-01],
#        [4.1696383e-04, 9.9958307e-01],
#        [3.4655720e-08, 1.0000000e+00],
#        [1.8036308e-06, 9.9999821e-01],
#        [5.1837790e-01, 4.8162213e-01],
#        [1.1638478e-05, 9.9998832e-01],
#        [1.0000000e+00, 5.3234462e-08],
#        [1.0000000e+00, 1.6775160e-09],
#        [9.9999964e-01, 3.8746447e-07],
#        [1.4855887e-01, 8.5144109e-01],
#        [4.2462967e-02, 9.5753706e-01],
#        [9.9999988e-01, 6.9175961e-08],
#        [1.0000000e+00, 1.5142828e-11],
#        [1.0000000e+00, 4.0106833e-08],
#        [4.8274350e-01, 5.1725650e-01],
#        [1.0000000e+00, 1.0599559e-08],
#        [9.9998963e-01, 1.0413096e-05],
#        [1.6195759e-04, 9.9983799e-01],
#        [3.1334374e-02, 9.6866566e-01],
#        [1.0000000e+00, 5.2074678e-10],
#        [6.9990919e-10, 1.0000000e+00],
#        [9.9669456e-01, 3.3054748e-03],
#        [1.0588566e-06, 9.9999893e-01]], dtype=float32)

# %%
accuracy_score(np.argmax(y_val, axis=1), np.argmax(Y_val_pred, axis=1))
# Out:
# 0.9047619047619048

# %%
Y_pred = model.predict(X_test)

# %%
tta_steps = 10
predictions = []

for i in tqdm(range(tta_steps)):
    preds = model.predict(train_generator.flow(X_test, batch_size=BATCH_SIZE, shuffle=False),
                                    steps = len(X_test)/BATCH_SIZE)
    
    predictions.append(preds)
    gc.collect()
    
Y_pred_tta = np.mean(predictions, axis=0)
# Out:
# 100%|██████████| 10/10 [02:08<00:00, 12.88s/it]

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for Skin Cancer')
# Out:
# Confusion matrix, without normalization
# [[249  24]
#  [ 25 640]]

# %%
cm = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))

cm_plot_label =['benign', 'malignant']
plot_confusion_matrix(cm, cm_plot_label, title ='Confusion Metrix for Skin Cancer')
# Out:
# Confusion matrix, without normalization
# [[256  17]
#  [ 23 642]]

# %% [markdown]
# ### Classification Report

# %%
from sklearn.metrics import classification_report
classification_report( np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.92      0.94      0.93       273\n           1       0.97      0.97      0.97       665\n\n    accuracy                           0.96       938\n   macro avg       0.95      0.95      0.95       938\nweighted avg       0.96      0.96      0.96       938\n'

# %% [markdown]
# ### ROC and AUC

# %%
from sklearn.metrics import roc_auc_score, auc
from sklearn.metrics import roc_curve
roc_log = roc_auc_score(np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))
false_positive_rate, true_positive_rate, threshold = roc_curve(np.argmax(Y_test, axis=1), np.argmax(Y_pred_tta, axis=1))
area_under_curve = auc(false_positive_rate, true_positive_rate)

plt.plot([0, 1], [0, 1], 'r--')
plt.plot(false_positive_rate, true_positive_rate, label='AUC = {:.3f}'.format(area_under_curve))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()
#plt.savefig(ROC_PLOT_FILE, bbox_inches='tight')
plt.close()

# %%
i=0
prop_class=[]
mis_class=[]

for i in range(len(Y_test)):
    if(np.argmax(Y_test[i])==np.argmax(Y_pred_tta[i])):
        prop_class.append(i)
    if(len(prop_class)==8):
        break

i=0
for i in range(len(Y_test)):
    if(not np.argmax(Y_test[i])==np.argmax(Y_pred_tta[i])):
        mis_class.append(i)
    if(len(mis_class)==8):
        break

# # Display first 8 images of benign
w=60
h=40
fig=plt.figure(figsize=(18, 10))
columns = 4
rows = 2

def Transfername(namecode):
    if namecode==0:
        return "Benign"
    else:
        return "Malignant"
    
for i in range(len(prop_class)):
    ax = fig.add_subplot(rows, columns, i+1)
    ax.set_title("Predicted result:"+ Transfername(np.argmax(Y_pred_tta[prop_class[i]]))
                       +"\n"+"Actual result: "+ Transfername(np.argmax(Y_test[prop_class[i]])))
    plt.imshow(X_test[prop_class[i]], interpolation='nearest')
plt.show()
